# %% [markdown]
# work flow
#
# 1. data
# 2. data pre processing
# 3. data analysis
# 4. train-test-split
# 5. logistic regression model
# 6. evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# creditdata = pd.read_csv('/content/credit_data.csv')
credit_data = pd.read_csv('/content/credit_data.csv', on_bad_lines='skip')

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 39697  39927 -1.466679  2.425732  0.877724  3.950765  0.762477  1.162748
# 39698  39927 -0.523165 -0.100021  0.892966 -1.900405 -0.156870 -0.783894
# 39699  39928 -2.768425 -1.007072  2.151127  0.117797  1.283178  1.869731
# 39700  39928  1.201327  0.158614 -0.325263  0.471667  0.086446 -0.770357
# 39701  39929  1.097669 -1.315782  0.659681 -0.683915 -1.342612  0.332629
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 39697  0.575625 -0.288354 -1.357990  ...  0.186051  0.571010 -0.107517
# 39698  0.917683 -0.308345 -1.305284  ... -0.082504 -0.414677 -0.063392
# 39699 -0.562240  0.820374  0.348797  ... -0.182963  0.778210  0.904077
# 39700  0.422151 -0.205277 -0.451865  ...  0.027664 -0.018485 -0.199382
# 39701 -1.110900  0.194811 -0.248825  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39702 entries, 0 to 39701
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    39702 non-null  int64
#  1   V1      39702 non-null  float64
#  2   V2      39702 non-null  float64
#  3   V3      39702 non-null  float64
#  4   V4      39702 non-null  float64
#  5   V5      39702 non-null  float64
#  6   V6      39702 non-null  float64
#  7   V7      39702 non-null  float64
#  8   V8      39702 non-null  float64
#  9   V9      39702 non-null  float64
#  10  V10     39702 non-null  float64
#  11  V11     39702 non-null  float64
#  12  V12     39702 non-null  float64
#  13  V13     39701 non-null  float64
#  14  V14     39701 non-null  float64
#  15  V15     39701 non-null  float64
#  16  V16     39701 non-null  float64
#  17  V17     39701 non-null  float64
#  18  V18     39701 non-null  float64
#  19  V19     39701 non-null  float64
# ...

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_data['Class'].value_counts()
# Out:
# 0.0    39597
# 1.0      104
# Name: Class, dtype: int64

# %% [markdown]
# Results shows that the data set is highly imbalance
#
# 0--> legit
#
# 1--> fraudulent

# %%
#seprating the legit and fraudulent transactioni
legit = credit_data[credit_data.Class == 0]
fraud = credit_data[credit_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (39597, 31)
# (104, 31)

# %%
legit.Amount.describe()
# Out:
# count    39597.000000
# mean        87.420700
# std        234.514383
# min          0.000000
# 25%          7.420000
# 50%         23.500000
# 75%         79.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     104.000000
# mean       97.070769
# std       255.012160
# min         0.000000
# 25%         1.000000
# 50%         3.775000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    25514.725686 -0.194310  0.036967   0.744162  0.174545 -0.217414
# 1.0    20683.201923 -7.697309  5.766703 -10.853666  5.865850 -5.424996
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.107151 -0.093182  0.031783  0.222434  ...  0.046047 -0.031386
# 1.0   -2.275717 -7.641867  3.827809 -2.924282  ...  0.663205  0.626795
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.111706 -0.039470  0.007851  0.135895  0.022779  0.005987  0.003920
# 1.0   -0.345972 -0.342944 -0.230514  0.299242  0.176522  0.811431  0.099914
#
#           Amount
# Class
# 0.0    87.420700
# 1.0    97.070769
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions.

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  39597.000000  39597.000000  39597.000000  39597.000000  39597.000000
# mean   25514.725686     -0.194310      0.036967      0.744162      0.174545
# std    12629.388641      1.728441      1.502340      1.296174      1.363158
# min        0.000000    -28.344757    -40.978852    -27.747084     -5.172595
# 25%    14747.000000     -0.962490     -0.526669      0.239256     -0.719932
# 50%    30625.000000     -0.230343      0.098694      0.820936      0.179525
# 75%    35631.000000      1.161037      0.738903      1.449635      1.063883
# max    39928.000000      1.960497     14.845545      4.101716     13.143668
#
#                  V5            V6            V7            V8            V9  \
# count  39597.000000  39597.000000  39597.000000  39597.000000  39597.000000
# mean      -0.217414      0.107151     -0.093182      0.031783      0.222434
# ...

# %%
fraud.describe()
# Out:
#                Time          V1          V2          V3          V4  \
# count    104.000000  104.000000  104.000000  104.000000  104.000000
# mean   20683.201923   -7.697309    5.766703  -10.853666    5.865850
# std    10348.117012    9.386856    4.832232    9.681368    2.876114
# min      406.000000  -30.552380   -5.198360  -31.103685    0.817253
# 25%    11089.000000  -15.503928    2.468074  -20.623644    3.771144
# 50%    20691.000000   -3.359030    4.139352   -6.083413    6.027905
# 75%    28666.500000   -0.414863    8.848901   -3.225874    6.567806
# max    39729.000000    1.234235   16.713389    2.041003   11.927512
#
#                V5          V6          V7          V8          V9  ...  \
# count  104.000000  104.000000  104.000000  104.000000  104.000000  ...
# mean    -5.424996   -2.275717   -7.641867    3.827809   -2.924282  ...
# std      6.936827    1.639228    7.192931    6.216567    2.289303  ...
# ...

# %%
#building a sample data set containing similar distribution of legit and transaction
legit_sample = legit.sample(n=492)

# %%
print(legit_sample.shape)
# Out:
# (492, 31)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    104
# Name: Class, dtype: int64

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 33131  37103 -0.921732  0.080744  1.200659 -2.217900  0.100078 -1.544628
# 28083  34846  0.989280 -0.872357  0.714635  0.014965 -0.837503  0.796566
# 39261  39767  1.012776 -0.756692  0.468606 -0.155811 -0.306044  1.243997
# 862      654 -1.503011 -1.386189  2.339168  1.714979  1.666073  0.241151
# 17980  29086  1.252733  0.293642  0.053431  0.516684  0.076941 -0.295868
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 33131  0.855621 -0.332452 -1.523350  ... -0.695604 -1.707935  0.316327
# 28083 -0.812352  0.434269  1.182616  ... -0.157664 -0.471900 -0.055444
# 39261 -0.644278  0.335878  0.859286  ... -0.165900 -0.403768 -0.179419
# 862   -1.017505  0.439214  0.635640  ... -0.161417 -0.349421  0.281749
# 17980 -0.004559 -0.029834  0.067626  ... -0.296023 -0.815108  0.093337
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
# 39183  39729 -0.964567 -1.643541 -0.187727  1.158253 -2.458336  0.852222
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473  0.614573  0.028521
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888 -0.845753  0.190674
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641 -0.962960 -0.110045
# 33276 -5.283435  0.131619  0.658176  ... -0.734308 -0.599926 -4.908301
# 39183  2.785163 -0.303609  0.940006  ...  0.447180  0.536204  1.634061
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24876.152439 -0.084838 -0.015504   0.774344  0.077311 -0.175373
# 1.0    20683.201923 -7.697309  5.766703 -10.853666  5.865850 -5.424996
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.178743 -0.046413  0.003094  0.162235  ...  0.085806 -0.046568
# 1.0   -2.275717 -7.641867  3.827809 -2.924282  ...  0.663205  0.626795
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.114574 -0.027650  0.001057  0.125575  0.031004  0.015307  0.011020
# 1.0   -0.345972 -0.342944 -0.230514  0.299242  0.176522  0.811431  0.099914
#
#           Amount
# Class
# 0.0    92.966260
# 1.0    97.070769
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 33131  37103 -0.921732  0.080744  1.200659 -2.217900  0.100078 -1.544628
# 28083  34846  0.989280 -0.872357  0.714635  0.014965 -0.837503  0.796566
# 39261  39767  1.012776 -0.756692  0.468606 -0.155811 -0.306044  1.243997
# 862      654 -1.503011 -1.386189  2.339168  1.714979  1.666073  0.241151
# 17980  29086  1.252733  0.293642  0.053431  0.516684  0.076941 -0.295868
# ...      ...       ...       ...       ...       ...       ...       ...
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
# 39183  39729 -0.964567 -1.643541 -0.187727  1.158253 -2.458336  0.852222
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 33131    0.0
# 28083    0.0
# 39261    0.0
# 862      0.0
# 17980    0.0
#         ...
# 30473    1.0
# 30496    1.0
# 31002    1.0
# 33276    1.0
# 39183    1.0
# Name: Class, Length: 596, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state=15)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
train_prediction = model.predict(X_train)
train_accuracy = accuracy_score(train_prediction, Y_train)
print(train_accuracy)
# Out:
# 0.9888143176733781

# %%
test_prediction = model.predict(X_test)
test_accuracy = accuracy_score(test_prediction, Y_test)
print(test_accuracy)
# Out:
# 0.959731543624161
